# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\thepr\\Downloads\\Mobiles_Dataset.csv")
df
# Out:
#                            Product Name Actual price Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2       Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
# ..                                  ...          ...            ...    ...
# 979                        Kechaoda A27       ₹1,499           ₹967    4.0
# 980                        Kechaoda A27       ₹1,499           ₹975    4.0
# 981                        Kechaoda A27       ₹1,499           ₹975    4.0
# 982                        Kechaoda A27       ₹1,499           ₹930    4.0
# 983                        Kechaoda A27       ₹1,499           ₹967    4.0
#
#              Rating        Reviews  RAM (GB)  Storage (GB)  \
# ...

# %%
df.head()
# Out:
#                          Product Name Actual price Discount price  Stars  \
# 0     Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1      Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2     Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3  OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4  OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
#
#            Rating        Reviews  RAM (GB)  Storage (GB)  Display Size (inch)  \
# 0  44,793 Ratings  2,402 Reviews         0           128                 6.10
# 1  44,793 Ratings  2,402 Reviews         0           128                 6.10
# 2  44,793 Ratings  2,402 Reviews         0           128                 6.10
# 3   1,005 Ratings     41 Reviews         4           128                 6.56
# 4   1,005 Ratings     41 Reviews         4            64                 6.56
#
# ...

# %%
df.tail()
# Out:
#      Product Name Actual price Discount price  Stars          Rating  \
# 979  Kechaoda A27       ₹1,499           ₹967    4.0  11,022 Ratings
# 980  Kechaoda A27       ₹1,499           ₹975    4.0  11,022 Ratings
# 981  Kechaoda A27       ₹1,499           ₹975    4.0  11,022 Ratings
# 982  Kechaoda A27       ₹1,499           ₹930    4.0  11,022 Ratings
# 983  Kechaoda A27       ₹1,499           ₹967    4.0  11,022 Ratings
#
#          Reviews  RAM (GB)  Storage (GB)  Display Size (inch)       Camera  \
# 979  693 Reviews         0             0                 0.66  0MP | 0MP
# 980  693 Reviews         0             0                 0.66          NaN
# 981  693 Reviews         0             0                 0.66          NaN
# 982  693 Reviews         0             0                 0.66  0MP | 0MP
# 983  693 Reviews         0             0                 0.66  0MP | 0MP
#
#                                            Description  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Name         984 non-null    object
#  1   Actual price         984 non-null    object
#  2   Discount price       984 non-null    object
#  3   Stars                984 non-null    float64
#  4   Rating               984 non-null    object
#  5   Reviews              984 non-null    object
#  6   RAM (GB)             984 non-null    int64
#  7   Storage (GB)         984 non-null    int64
#  8   Display Size (inch)  984 non-null    float64
#  9   Camera               908 non-null    object
#  10  Description          984 non-null    object
#  11  Link                 984 non-null    object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 92.4+ KB

# %%
df.describe()
# Out:
#             Stars      RAM (GB)  Storage (GB)  Display Size (inch)
# count  984.000000    984.000000    984.000000           984.000000
# mean     4.254980    101.594512    160.531504             6.043116
# std      0.199734   2111.931293    112.522574             1.581261
# min      3.400000      0.000000      0.000000             0.660000
# 25%      4.200000      4.000000    128.000000             6.500000
# 50%      4.300000      8.000000    128.000000             6.670000
# 75%      4.400000      8.000000    256.000000             6.720000
# max      5.000000  46875.000000    512.000000             7.820000

# %%
print(df.shape)
# Out:
# (984, 12)

# %%
df.iloc[55:65]
# Out:
#                                          Product Name Actual price  \
# 55         SAMSUNG Galaxy M14 5G (Berry Blue, 128 GB)      ₹18,990
# 56  itel Aura 05i|Leather Finish|4000 Mah Battery|...       ₹6,799
# 57                  realme C61 (Marble Black, 128 GB)      ₹10,999
# 58                   realme C61 (Marble Black, 64 GB)       ₹8,999
# 59  LAVA A1 Josh BOL Keypad Mobile|1000 mAh Batter...       ₹1,399
# 60         Tecno Spark 20C (Magic Skin Green, 128 GB)      ₹10,499
# 61              vivo Y200 Pro 5G (Silk Green, 128 GB)            0
# 62              vivo Y200 Pro 5G (Silk Green, 128 GB)            0
# 63         Tecno Spark 20 Pro 5G (Neon Green, 128 GB)      ₹19,999
# 64                  OPPO F27 Pro+ (Dusk Pink, 256 GB)      ₹34,999
#
#    Discount price  Stars          Rating        Reviews  RAM (GB)  \
# 55        ₹14,990    4.2  24,580 Ratings  1,539 Reviews         6
# 56         ₹5,749    4.0     727 Ratings     19 Reviews         2
# ...

# %%
f_data = df[df['Stars']>4]
f_data
# Out:
#                                    Product Name Actual price Discount price  \
# 0               Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999
# 1                Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999
# 2               Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999
# 5               OnePlus 12R (Cool Blue, 128 GB)      ₹39,999        ₹38,989
# 6    SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)      ₹17,490        ₹10,990
# ..                                          ...          ...            ...
# 968              Apple iPhone 12 (Blue, 128 GB)      ₹54,900        ₹44,999
# 969              Apple iPhone 12 (Black, 64 GB)      ₹49,900        ₹38,999
# 970             Apple iPhone 12 (Black, 256 GB)      ₹64,900        ₹52,999
# 974                                LAVA A3 vibe       ₹1,319         ₹1,212
# 977                               Kechaoda K115       ₹1,350         ₹1,069
#
# ...

# %%
d_data = df[['Product Name', 'Actual price', 'Discount price', 'Stars', 'Rating', 'Reviews', 'RAM (GB)', 'Storage (GB)', 'Display Size (inch)', 'Camera']]
d_data
# Out:
#                            Product Name Actual price Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2       Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
# ..                                  ...          ...            ...    ...
# 979                        Kechaoda A27       ₹1,499           ₹967    4.0
# 980                        Kechaoda A27       ₹1,499           ₹975    4.0
# 981                        Kechaoda A27       ₹1,499           ₹975    4.0
# 982                        Kechaoda A27       ₹1,499           ₹930    4.0
# 983                        Kechaoda A27       ₹1,499           ₹967    4.0
#
#              Rating        Reviews  RAM (GB)  Storage (GB)  \
# ...

# %%
df.isnull()
# Out:
#      Product Name  Actual price  Discount price  Stars  Rating  Reviews  \
# 0           False         False           False  False   False    False
# 1           False         False           False  False   False    False
# 2           False         False           False  False   False    False
# 3           False         False           False  False   False    False
# 4           False         False           False  False   False    False
# ..            ...           ...             ...    ...     ...      ...
# 979         False         False           False  False   False    False
# 980         False         False           False  False   False    False
# 981         False         False           False  False   False    False
# 982         False         False           False  False   False    False
# 983         False         False           False  False   False    False
#
#      RAM (GB)  Storage (GB)  Display Size (inch)  Camera  Description   Link
# ...

# %%
df.fillna(0, inplace=True)
df
# Out:
#                            Product Name Actual price Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2       Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
# ..                                  ...          ...            ...    ...
# 979                        Kechaoda A27       ₹1,499           ₹967    4.0
# 980                        Kechaoda A27       ₹1,499           ₹975    4.0
# 981                        Kechaoda A27       ₹1,499           ₹975    4.0
# 982                        Kechaoda A27       ₹1,499           ₹930    4.0
# 983                        Kechaoda A27       ₹1,499           ₹967    4.0
#
#              Rating        Reviews  RAM (GB)  Storage (GB)  \
# ...

# %%
d_data = df[['Product Name', 'Actual price', 'Discount price', 'Stars', 'Rating', 'Reviews', 'RAM (GB)', 'Storage (GB)', 'Display Size (inch)', 'Camera']]
d_data
# Out:
#                            Product Name Actual price Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2       Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
# ..                                  ...          ...            ...    ...
# 979                        Kechaoda A27       ₹1,499           ₹967    4.0
# 980                        Kechaoda A27       ₹1,499           ₹975    4.0
# 981                        Kechaoda A27       ₹1,499           ₹975    4.0
# 982                        Kechaoda A27       ₹1,499           ₹930    4.0
# 983                        Kechaoda A27       ₹1,499           ₹967    4.0
#
#              Rating        Reviews  RAM (GB)  Storage (GB)  \
# ...

# %%
# Remove unwanted characters like commas, currency symbols, and spaces
df['Actual price'] = df['Actual price'].replace({'\$': '', ',': '', '₹': '', ' ': ''}, regex=True)

# Convert the cleaned column to numeric
df['Actual price'] = pd.to_numeric(df['Actual price'], errors='coerce')

# Check the conversion result
print(df['Actual price'])

# Now you can filter the DataFrame
d_data = df[df['Actual price'] > 10000]
d_data
# Out:
# 0      79600
# 1      79600
# 2      79600
# 3      19999
# 4      16999
#        ...
# 979     1499
# 980     1499
# 981     1499
# 982     1499
# 983     1499
# Name: Actual price, Length: 984, dtype: int64
#                                  Product Name  Actual price Discount price  \
# 0             Apple iPhone 15 (Green, 128 GB)         79600        ₹65,999
# 1              Apple iPhone 15 (Blue, 128 GB)         79600        ₹65,999
# 2             Apple iPhone 15 (Black, 128 GB)         79600        ₹65,999
# 3          OnePlus N20 SE (JADE WAVE, 128 GB)         19999        ₹11,489
# 4          OnePlus N20 SE (BLUE OASIS, 64 GB)         16999        ₹12,999
# ..                                        ...           ...            ...
# 964        SAMSUNG Galaxy A03s (Black, 32 GB)         13499        ₹11,499
# 967  Motorola G60 (Frosted Champagne, 128 GB)         21999        ₹14,999
# 968            Apple iPhone 12 (Blue, 128 GB)         54900        ₹44,999
# ...

# %%
d_data = df[(df['Actual price'] > 50000) & (df['Actual price'] < 100000)]
d_data
# Out:
#                          Product Name  Actual price Discount price  Stars  \
# 0     Apple iPhone 15 (Green, 128 GB)         79600        ₹65,999    4.6
# 1      Apple iPhone 15 (Blue, 128 GB)         79600        ₹65,999    4.6
# 2     Apple iPhone 15 (Black, 128 GB)         79600        ₹65,999    4.6
# 19   OnePlus 12 (Silky Black, 512 GB)         69999        ₹59,629    4.6
# 20   OnePlus 12 (Silky Black, 512 GB)         69999        ₹59,629    4.6
# ..                                ...           ...            ...    ...
# 961    Apple iPhone 13 (Blue, 128 GB)         59600        ₹52,999    4.6
# 962    Apple iPhone 13 (Blue, 256 GB)         69600        ₹59,999    4.6
# 963    Apple iPhone 13 (Blue, 256 GB)         69600        ₹59,999    4.6
# 968    Apple iPhone 12 (Blue, 128 GB)         54900        ₹44,999    4.6
# 970   Apple iPhone 12 (Black, 256 GB)         64900        ₹52,999    4.6
#
#                Rating         Reviews  RAM (GB)  Storage (GB)  \
# ...

# %%
d_data = df[df['Actual price'] > 80000]
d_data
# Out:
#                                           Product Name  Actual price  \
# 28               Apple iPhone 15 Plus (Yellow, 128 GB)         89600
# 39   SAMSUNG Galaxy S24 Ultra 5G (Titanium Black, 2...        134999
# 80               SAMSUNG Galaxy S23 5G (Cream, 128 GB)         89999
# 81               SAMSUNG Galaxy S23 5G (Cream, 256 GB)         95999
# 114  SAMSUNG Galaxy S24 Ultra 5G (Titanium Violet, ...        134999
# 156              Apple iPhone 14 Plus (Purple, 512 GB)        109600
# 167      SAMSUNG Galaxy S23 5G (Phantom Black, 128 GB)         89999
# 168      SAMSUNG Galaxy S23 5G (Phantom Black, 256 GB)         95999
# 192              Google Pixel 7 Pro (Obsidian, 128 GB)         84999
# 292        SAMSUNG Galaxy S23 Ultra 5G (Cream, 256 GB)        149999
# 355                OnePlus Open (Emerald Dusk, 512 GB)        149999
# 436               SAMSUNG Galaxy S23 FE (Mint, 256 GB)         84999
# 492                    Apple iPhone 15 (Green, 256 GB)         89600
# ...

# %%
d_data = df[(df['Stars']>3) & (df['Stars']<4)]
d_data
# Out:
#                                           Product Name  Actual price  \
# 21   itel it5027 6.1cm Screen,1200mAh Battery Wirel...          1499
# 25                                           Nokia 105          1699
# 38            realme 13 Pro 5G (Emerald Green, 512 GB)         34999
# 79                                         Micromax J3          1549
# 92   Nokia 106 4G Keypad Mobile, Long-Lasting Batte...          2999
# 94                                             Vox V16          1649
# 139                                        itel it5262          1599
# 143      realme Narzo N63 4G (Twilight Purple, 128 GB)         10999
# 144      realme Narzo N63 4G (Twilight Purple, 128 GB)         10999
# 164                                          I Kall A2          2999
# 204                            I Kall K29-Pro 4G Phone          2599
# 206                                         itel ACE 2          1199
# 219                     Nokia C32 (Beach Pink, 128 GB)         10999
# ...

# %%
d_data = df['Product Name'].value_counts()
d_data
# Out:
# Product Name
# OPPO K12x 5G with 45W SUPERVOOC Charger In-The-Box (Breeze Blue, 256 GB)    31
# Nokia 105 Single SIM, Keypad Mobile Phone with Wireless FM Radio             7
# Kechaoda A27                                                                 6
# itel it5330 | 2.8 inch Big Display | 1900 mAh Battery | Kingvoice            6
# REDMI Note 13 Pro 5G (Coral Purple, 256 GB)                                  5
#                                                                             ..
# POCO F6 5G (Black, 512 GB)                                                   1
# OPPO Reno8T 5G (Sunrise Gold, 128 GB)                                        1
# OnePlus Nord CE4 lite 5G (SUPER SILVER, 256 GB)                              1
# IQOO Z9X (Storm Grey, 128 GB)                                                1
# Apple iPhone 15 (Green, 128 GB)                                              1
# Name: count, Length: 657, dtype: int64

# %%
d_data = df['Product Name'].unique()
d_data
# Out:
# array(['Apple iPhone 15 (Green, 128 GB)',
#        'Apple iPhone 15 (Blue, 128 GB)',
#        'Apple iPhone 15 (Black, 128 GB)',
#        'OnePlus N20 SE (JADE WAVE, 128 GB)',
#        'OnePlus N20 SE (BLUE OASIS, 64 GB)',
#        'OnePlus 12R (Cool Blue, 128 GB)',
#        'SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)',
#        'CMF by Nothing Phone 1 (Blue, 128 GB)',
#        'vivo Y200e 5G (Black Diamond, 128 GB)',
#        'OPPO F25 Pro 5G (Ocean Blue, 128 GB)',
#        'Motorola G85 5G (Urban Grey, 128 GB)',
#        'Motorola g04s (Satin Blue, 64 GB)',
#        'Motorola g64 5G (Ice Lilac, 256 GB)',
#        'MOTOROLA G04 (Sunrise Orange, 64 GB)',
#        'Nothing Phone (2a) 5G (Blue, 128 GB)',
#        'Nothing Phone (2a) 5G (Blue, 256 GB)',
#        'OnePlus 12 (Silky Black, 512 GB)',
#        'itel it5027 6.1cm Screen,1200mAh Battery Wireless FM Radio with Recording,KingVoice',
#        'realme 12 Pro+ 5G (Navigator Beige, 256 GB)', 'Nokia 105',
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Product Name           0
# Actual price           0
# Discount price         0
# Stars                  0
# Rating                 0
# Reviews                0
# RAM (GB)               0
# Storage (GB)           0
# Display Size (inch)    0
# Camera                 0
# Description            0
# Link                   0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Product Name           0
# Actual price           0
# Discount price         0
# Stars                  0
# Rating                 0
# Reviews                0
# RAM (GB)               0
# Storage (GB)           0
# Display Size (inch)    0
# Camera                 0
# Description            0
# Link                   0
# dtype: int64

# %%
df.size
# Out:
# 11808

# %%
df['Actual price'].unique()
# Out:
# array([ 79600,  19999,  16999,  39999,  17490,  21999,  25999,  23999,
#         28999,  20999,   9999,  27999,  69999,   1499,  37999,  35999,
#          1699,   7999,   8999,  89600,  59999,   7299,  22999,   1649,
#         30999,  34999, 134999,  26999,  24999,  33999,  54999,  17990,
#         18990,   6799,  10999,   1399,  10499,      0,  32999,   7499,
#          1599,   1549,  89999,  95999,  17999,  15999,  11999,   1199,
#          2999,  53999,  46999,  51999,  14999,   6999,  18999,  17499,
#         20499,  41999,   1999,  13499,  79999,  44999,  47999,  18499,
#          1899,  43999,  13999,  23000, 109600,  12999,  84999,   2099,
#          2599,  12499,  64999,  21499,   1240,  36999,  40999,  14499,
#         69600,  45999,  15499,  18490,   1799,  29999, 149999,  55999,
#          1630,   3999,  25990,   1790,  24499,   1349,   1559,  38999,
#         42999,  19990,   2199,  28990,   2699,  75999,  31999,  66999,
# ...

# %%
df['Discount price'].unique()
# Out:
# array(['₹65,999', '₹11,489', '₹12,999', '₹38,989', '₹10,990', '₹15,999',
#        '₹17,999', '₹20,999', '₹19,999', '₹23,999', '₹6,999', '₹16,999',
#        '₹25,999', '₹59,629', '₹1,177', '₹33,999', '₹31,999', '₹1,399',
#        '₹6,699', '₹73,999', '₹7,299', '₹30,469', '₹37,999', '₹6,419',
#        '₹1,208', '₹28,999', '₹26,999', '₹1,29,999', '₹21,994', '₹21,999',
#        '₹18,999', '₹27,999', '₹42,999', '₹47,999', '₹11,895', '₹12,888',
#        '₹14,990', '₹5,749', '₹8,999', '₹7,699', '₹960', '₹7,999',
#        '₹24,999', '₹29,999', '₹32,856', '₹30,999', '₹27,118', '₹34,999',
#        '₹6,899', '₹1,449', '₹842', '₹48,999', '₹53,999', '₹12,499',
#        '₹13,999', '₹14,900', '₹13,990', '₹11,999', '₹18,249', '₹8,649',
#        '₹896', '₹895', '₹19,499', '₹2,632', '₹809', '₹36,999', '₹41,999',
#        '₹46,999', '₹12,470', '₹6,599', '₹29,699', '₹1,060', '₹14,999',
#        '₹15,499', '₹13,499', '₹16,499', '₹10,999', '₹28,630', '₹38,559',
# ...

# %%
df['Discount price'] = df['Discount price'].replace({'\$': '', ',': '', '₹': '', ' ': ''}, regex=True)


df['Discount price'] = pd.to_numeric(df['Discount price'], errors='coerce')
df
# Out:
#                            Product Name  Actual price  Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)         79600         65999.0    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)         79600         65999.0    4.6
# 2       Apple iPhone 15 (Black, 128 GB)         79600         65999.0    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)         19999         11489.0    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)         16999         12999.0    4.0
# ..                                  ...           ...             ...    ...
# 979                        Kechaoda A27          1499           967.0    4.0
# 980                        Kechaoda A27          1499           975.0    4.0
# 981                        Kechaoda A27          1499           975.0    4.0
# 982                        Kechaoda A27          1499           930.0    4.0
# 983                        Kechaoda A27          1499           967.0    4.0
#
# ...

# %%
g_data =df[df['Discount price']>50000]
g_data
# Out:
#                             Product Name  Actual price  Discount price  Stars  \
# 0        Apple iPhone 15 (Green, 128 GB)         79600         65999.0    4.6
# 1         Apple iPhone 15 (Blue, 128 GB)         79600         65999.0    4.6
# 2        Apple iPhone 15 (Black, 128 GB)         79600         65999.0    4.6
# 19      OnePlus 12 (Silky Black, 512 GB)         69999         59629.0    4.6
# 20      OnePlus 12 (Silky Black, 512 GB)         69999         59629.0    4.6
# ..                                   ...           ...             ...    ...
# 960  Apple iPhone 13 (Starlight, 128 GB)         59600         52999.0    4.6
# 961       Apple iPhone 13 (Blue, 128 GB)         59600         52999.0    4.6
# 962       Apple iPhone 13 (Blue, 256 GB)         69600         59999.0    4.6
# 963       Apple iPhone 13 (Blue, 256 GB)         69600         59999.0    4.6
# 970      Apple iPhone 12 (Black, 256 GB)         64900         52999.0    4.6
#
# ...

# %%
df['Discount price'].unique()
# Out:
# array([ 65999.,  11489.,  12999.,  38989.,  10990.,  15999.,  17999.,
#         20999.,  19999.,  23999.,   6999.,  16999.,  25999.,  59629.,
#          1177.,  33999.,  31999.,   1399.,   6699.,  73999.,   7299.,
#         30469.,  37999.,   6419.,   1208.,  28999.,  26999., 129999.,
#         21994.,  21999.,  18999.,  27999.,  42999.,  47999.,  11895.,
#         12888.,  14990.,   5749.,   8999.,   7699.,    960.,   7999.,
#         24999.,  29999.,  32856.,  30999.,  27118.,  34999.,   6899.,
#          1449.,    842.,  48999.,  53999.,  12499.,  13999.,  14900.,
#         13990.,  11999.,  18249.,   8649.,    896.,    895.,  19499.,
#          2632.,    809.,  36999.,  41999.,  46999.,  12470.,   6599.,
#         29699.,   1060.,  14999.,  15499.,  13499.,  16499.,  10999.,
#         28630.,  38559.,  33316.,   1165.,  32999.,   9469.,  69999.,
#         61357.,  25950.,  13784.,   1450.,   5699.,   8178.,   6499.,
# ...

# %%
df.Camera.unique()
# Out:
# array(['48MP + 12MP', '50MP ', '50MP + 2MP', '64MP + 8MP', '50MP + 8MP',
#        '8MP | 16MP  ', '16MP ', '50MP | 32MP  ', '64MP ', '3MP + 0MP',
#        '0MP | 0MP  ', 0, '13MP ', '50MP + 12MP', '3MP ', '200MP + 50MP',
#        '8MP | 20MP  ', '50MP + 50MP', '3MP | 2MP  ', '32MP ',
#        '64MP + 2MP', '108MP ', '8MP + 2MP', '08MP | 16MP  ',
#        '50MP + 10MP', '08MP | 5MP  ', '8MP ', '13MP + 2MP', '200MP ',
#        '8MP | 5MP  ', '13MP | 13MP  ', '2MP + 2MP', '12MP + 12MP',
#        '2MP | 16MP  ', '50MP + 48MP', '2MP ', '50MP + 13MP', '50MP + 5MP',
#        '64MP + 13MP', '8MP + 0MP', '108MP + 2MP', '200MP + 10MP',
#        '48MP + 8MP', '32MP + 2MP', '48MP ', '08MP ', '2MP | 8MP  ',
#        '08MP | 8MP  ', '108MP + 5MP', '13MP + 13MP', '108MP + 8MP',
#        '50MP + 64MP', '5MP + 0MP', '8MP | 8MP  ', '48MP + 5MP'],
#       dtype=object)

# %%
df["discount rate"] = ((df["Actual price"] - df["Discount price"]) / df["Actual price"]) * 100
df
# Out:
#                            Product Name  Actual price  Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)         79600         65999.0    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)         79600         65999.0    4.6
# 2       Apple iPhone 15 (Black, 128 GB)         79600         65999.0    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)         19999         11489.0    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)         16999         12999.0    4.0
# ..                                  ...           ...             ...    ...
# 979                        Kechaoda A27          1499           967.0    4.0
# 980                        Kechaoda A27          1499           975.0    4.0
# 981                        Kechaoda A27          1499           975.0    4.0
# 982                        Kechaoda A27          1499           930.0    4.0
# 983                        Kechaoda A27          1499           967.0    4.0
#
# ...

# %%
df['Actual price'].describe()
# Out:
# count       984.000000
# mean      23876.742886
# std       22389.898353
# min           0.000000
# 25%       10999.000000
# 50%       18999.000000
# 75%       29999.000000
# max      149999.000000
# Name: Actual price, dtype: float64

# %%
df['Discount price'].describe()
# Out:
# count       980.000000
# mean      21524.401020
# std       20843.490674
# min         809.000000
# 25%        8999.000000
# 50%       15999.000000
# 75%       27444.000000
# max      176999.000000
# Name: Discount price, dtype: float64

# %%
import matplotlib.pyplot as plt

df['Actual price'].plot(kind='line')
plt.title('Line Plot of Actual Price')
plt.xlabel('Index')
plt.ylabel('Actual Price')
plt.grid(True)
plt.show()

# %%
df['Discount price'].plot(kind='line')
plt.title('discounted price')
plt.xlabel('index')
plt.ylabel('price')
plt.show()

# %%
df['Actual price'].nlargest(10)
# Out:
# 292    149999
# 355    149999
# 667    149999
# 39     134999
# 114    134999
# 871    134999
# 156    109600
# 583    109600
# 753    109600
# 801    109600
# Name: Actual price, dtype: int64

# %%
df['Discount price'].nlargest(10)
# Out:
# 155    176999.0
# 154    164999.0
# 695    164999.0
# 39     129999.0
# 114    129999.0
# 871    129999.0
# 292    124999.0
# 355    124990.0
# 667    118949.0
# 542    109999.0
# Name: Discount price, dtype: float64

# %%
df['Discount price'].nsmallest(5)
# Out:
# 94     809.0
# 532    809.0
# 877    839.0
# 878    839.0
# 79     842.0
# Name: Discount price, dtype: float64

# %%
df['discount rate'].nlargest()
# Out:
# 204    55.021162
# 94     50.939964
# 532    50.939964
# 265    50.000625
# 435    50.000625
# Name: discount rate, dtype: float64

# %%
df['discount rate'].nsmallest()
# Out:
# 61    -inf
# 62    -inf
# 93    -inf
# 123   -inf
# 154   -inf
# Name: discount rate, dtype: float64

# %%
df['Storage (GB)'].nlargest()
# Out:
# 19    512
# 20    512
# 38    512
# 41    512
# 50    512
# Name: Storage (GB), dtype: int64

# %%
df['Storage (GB)'].unique()
# Out:
# array([128,  64, 256, 512,   0,  32,  16,   5,   4,   3, 125], dtype=int64)

# %%
df['Storage (GB)'].nsmallest()
# Out:
# 21    0
# 25    0
# 35    0
# 59    0
# 78    0
# Name: Storage (GB), dtype: int64

# %%
d_data = df[(df['Display Size (inch)']>5) & (df['RAM (GB)']>5)]
d_data
# Out:
#                                  Product Name  Actual price  Discount price  \
# 5             OnePlus 12R (Cool Blue, 128 GB)         39999         38989.0
# 7       CMF by Nothing Phone 1 (Blue, 128 GB)         19999         15999.0
# 8       CMF by Nothing Phone 1 (Blue, 128 GB)         21999         17999.0
# 9       vivo Y200e 5G (Black Diamond, 128 GB)         25999         20999.0
# 10      vivo Y200e 5G (Black Diamond, 128 GB)         23999         19999.0
# ..                                        ...           ...             ...
# 944          POCO F4 5G (Night Black, 128 GB)         32999         27999.0
# 948        Motorola G60 (Soft Silver, 128 GB)         21999         14999.0
# 955      vivo X70 Pro+ (Enigma Black, 256 GB)         84990         48999.0
# 956      vivo X70 Pro+ (Enigma Black, 256 GB)         84990         48999.0
# 967  Motorola G60 (Frosted Champagne, 128 GB)         21999         14999.0
#
# ...

# %%
d_data = df[df['Rating']>'2000 Ratings' ]
d_data
# Out:
#                                    Product Name  Actual price  Discount price  \
# 0               Apple iPhone 15 (Green, 128 GB)         79600         65999.0
# 1                Apple iPhone 15 (Blue, 128 GB)         79600         65999.0
# 2               Apple iPhone 15 (Black, 128 GB)         79600         65999.0
# 5               OnePlus 12R (Cool Blue, 128 GB)         39999         38989.0
# 6    SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)         17490         10990.0
# ..                                          ...           ...             ...
# 973                                Kechaoda K28          1399          1260.0
# 974                                LAVA A3 vibe          1319          1212.0
# 975                                Kechaoda A26          1499           930.0
# 976                                Kechaoda A26          1399           999.0
# 977                               Kechaoda K115          1350          1069.0
#
# ...

# %%
df['discount rate'].unique()
# Out:
# array([17.08668342, 42.55212761, 23.53079593,  2.52506313, 37.16409377,
#        20.00100005, 18.18264467, 19.2315089 , 16.66736114, 17.24197386,
#        14.28639459, 30.0030003 , 15.00075004,  7.69260356,  7.14311225,
#        14.81449735, 21.48098732, 10.52659281, 11.11141976, 17.65744556,
#        16.2520315 , 22.22469163, 17.41183036, 27.00270027, 23.82559564,
#        36.66727779, 12.05644609, 13.04404539, 26.7434809 ,  6.45182103,
#         6.89678954,  8.57167348,  3.70373114, 18.53772362, 21.42933676,
#        24.00096004, 22.2230453 , 23.81065765, 22.72830583, 17.64757787,
#        15.78988921, 21.81857852, 20.00033334, 33.8799333 , 28.36020011,
#        21.06371775, 15.44344757, 18.18347122, 14.44604956, 31.37955683,
#        23.8117916 ,        -inf, 14.28612246, 15.1519743 , 13.5345667 ,
#         8.82378893, 20.23883055,  7.8949446 ,  8.00106681, 18.89098789,
#        27.27520684,  9.38086304, 45.6423499 , 45.55606173, 43.75045573,
# ...

# %%
df['discount rate'].describe()
# Out:
# count    980.000000
# mean           -inf
# std             NaN
# min            -inf
# 25%       14.286395
# 50%       20.001000
# 75%       27.044637
# max       55.021162
# Name: discount rate, dtype: float64

# %%
d_data = df[df['discount rate']>20.0]
d_data
# Out:
#                                    Product Name  Actual price  Discount price  \
# 3            OnePlus N20 SE (JADE WAVE, 128 GB)         19999         11489.0
# 4            OnePlus N20 SE (BLUE OASIS, 64 GB)         16999         12999.0
# 6    SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)         17490         10990.0
# 7         CMF by Nothing Phone 1 (Blue, 128 GB)         19999         15999.0
# 14            Motorola g04s (Satin Blue, 64 GB)          9999          6999.0
# ..                                          ...           ...             ...
# 979                                Kechaoda A27          1499           967.0
# 980                                Kechaoda A27          1499           975.0
# 981                                Kechaoda A27          1499           975.0
# 982                                Kechaoda A27          1499           930.0
# 983                                Kechaoda A27          1499           967.0
#
# ...

# %%
d_data = df[df['Product Name'].str.startswith('Apple iPhone ')]
d_data
# Out:
#                                  Product Name  Actual price  Discount price  \
# 0             Apple iPhone 15 (Green, 128 GB)         79600         65999.0
# 1              Apple iPhone 15 (Blue, 128 GB)         79600         65999.0
# 2             Apple iPhone 15 (Black, 128 GB)         79600         65999.0
# 28      Apple iPhone 15 Plus (Yellow, 128 GB)         89600         73999.0
# 156     Apple iPhone 14 Plus (Purple, 512 GB)        109600         86499.0
# 257    Apple iPhone 14 ((PRODUCT)RED, 128 GB)         69600         59999.0
# 401       Apple iPhone 14 (Starlight, 128 GB)         69600         59999.0
# 453  Apple iPhone 14 Plus (Starlight, 128 GB)         79600         56499.0
# 492           Apple iPhone 15 (Green, 256 GB)         89600         75999.0
# 493           Apple iPhone 15 (Green, 256 GB)         89600         75999.0
# 581           Apple iPhone 15 (Black, 256 GB)         89600         75999.0
# ...

# %%
d_data = df[df['Product Name'].str.startswith('OnePlus ')]
d_data
# Out:
#                                           Product Name  Actual price  \
# 3                   OnePlus N20 SE (JADE WAVE, 128 GB)         19999
# 4                   OnePlus N20 SE (BLUE OASIS, 64 GB)         16999
# 5                      OnePlus 12R (Cool Blue, 128 GB)         39999
# 19                    OnePlus 12 (Silky Black, 512 GB)         69999
# 20                    OnePlus 12 (Silky Black, 512 GB)         69999
# 30            OnePlus 11R 5G (Galactic Silver, 128 GB)         39999
# 87   OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...         21999
# 131                 OnePlus 12 (Flowy Emerald, 512 GB)         69999
# 149    OnePlus Nord CE4 lite 5G (SUPER SILVER, 256 GB)         23999
# 217                 OnePlus 12 (Flowy Emerald, 256 GB)         64999
# 262                    OnePlus 12R (Cool Blue, 256 GB)         45999
# 269                 OnePlus 12 (Glacial White, 256 GB)         64999
# 283                    OnePlus 12R (Iron Gray, 128 GB)             0
# ...

# %%
d_data = df[df['Product Name'].str.startswith('SAMSUNG')]
d_data
# Out:
#                                           Product Name  Actual price  \
# 6           SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)         17490
# 39   SAMSUNG Galaxy S24 Ultra 5G (Titanium Black, 2...        134999
# 53          SAMSUNG Galaxy M14 5G (Berry Blue, 128 GB)         17990
# 54          SAMSUNG Galaxy M14 5G (Berry Blue, 128 GB)         17990
# 55          SAMSUNG Galaxy M14 5G (Berry Blue, 128 GB)         18990
# ..                                                 ...           ...
# 902            SAMSUNG Galaxy F04 (Jade Purple, 64 GB)         11499
# 915   SAMSUNG Galaxy A54 5G (Awesome Graphite, 256 GB)         45999
# 923         SAMSUNG Galaxy M14 5G (ICY Silver, 128 GB)         17990
# 924         SAMSUNG Galaxy M14 5G (ICY Silver, 128 GB)         17990
# 964                 SAMSUNG Galaxy A03s (Black, 32 GB)         13499
#
#      Discount price  Stars            Rating        Reviews  RAM (GB)  \
# ...

# %%
d_data = df[df['Product Name'].str.endswith('Berry Blue, 128 GB)')]
d_data
# Out:
#                                   Product Name  Actual price  Discount price  \
# 53  SAMSUNG Galaxy M14 5G (Berry Blue, 128 GB)         17990         11895.0
# 54  SAMSUNG Galaxy M14 5G (Berry Blue, 128 GB)         17990         12888.0
# 55  SAMSUNG Galaxy M14 5G (Berry Blue, 128 GB)         18990         14990.0
#
#     Stars          Rating        Reviews  RAM (GB)  Storage (GB)  \
# 53    4.2   6,481 Ratings    346 Reviews         4           128
# 54    4.2   6,481 Ratings    346 Reviews         4           128
# 55    4.2  24,580 Ratings  1,539 Reviews         6           128
#
#     Display Size (inch)       Camera  \
# 53                  6.6  50MP + 50MP
# 54                  6.6  50MP + 50MP
# 55                  6.6        50MP
#
#                                           Description  \
# 53  4 GB RAM | 128 GB ROM | Expandable Upto 256 GB...
# 54  4 GB RAM | 128 GB ROM | Expandable Upto 256 GB...
# 55  6 GB RAM | 128 GB ROM16.76 cm (6.6 inch) Displ...
#
# ...

# %%
d_data = df['Storage (GB)'].value_counts()
d_data.plot(kind = 'bar')
plt.xlabel('gb')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
d_data = df['RAM (GB)'].value_counts()
d_data.plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
d_data = df['Stars'].value_counts()
d_data.plot(kind = 'box')
# Out:
# <Axes: >

# %%
y = [df[df['Display Size (inch)'] == size].shape[0] for size in x]

plt.scatter(x, y)
plt.title('Scatter Plot of Display Size vs Frequency')
plt.xlabel('Display Size (inch)')
plt.ylabel('Frequency')
plt.show()
